# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
titanic=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic.set_index('PassengerId',inplace=True)
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
my_counts=titanic['Sex'].value_counts()
plt.pie(my_counts,labels=my_counts.index,autopct='%1.1f%%')
plt.title('presenting the male/female proportion')
plt.axis('equal')
# Out:
# (-1.099999561818627,
#  1.0999999791342203,
#  -1.0999994017696593,
#  1.0999998976119447)

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
import seaborn as sns
sns.scatterplot(data=titanic, x='Age', y='Fare', hue='Sex', palette={'male': 'blue', 'female': 'red'})
plt.title('scatterplot with the Fare payed and the Age, differ the plot color by gender')
plt.legend(title='Gender')

# %% [markdown]
# ### Step 7. How many people survived?

# %%
s=titanic[titanic['Survived']==1]
s['Survived'].sum()
# Out:
# 342

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
titanic['Fare'].plot(kind='hist')
plt.title('histogram with the Fare payed')
plt.grid(True)

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
pd.crosstab(index=[titanic['Survived'],titanic['Sex']],columns=titanic['Age'])
# Out:
# Age              0.42   0.67   0.75   0.83   0.92   1.00   2.00   3.00   \
# Survived Sex
# 0        female      0      0      0      0      0      0      4      1
#          male        0      0      0      0      0      2      3      0
# 1        female      0      0      2      0      0      2      2      1
#          male        1      1      0      2      1      3      1      4
#
# Age              4.00   5.00   ...  62.00  63.00  64.00  65.00  66.00  70.00  \
# Survived Sex                   ...
# 0        female      0      0  ...      0      0      0      0      0      0
#          male        3      0  ...      2      0      2      3      1      2
# 1        female      5      4  ...      1      2      0      0      0      0
#          male        2      0  ...      1      0      0      0      0      0
#
# Age              70.50  71.00  74.00  80.00
# Survived Sex
# 0        female      0      0      0      0
#          male        1      2      1      0
# ...

# %%
titanic['Survived'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.scatterplot(data=titanic,x='Sex',y='Age',hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>
